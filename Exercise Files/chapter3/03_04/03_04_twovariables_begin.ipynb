# %% [markdown]
# ## Python statistics essential training - 03_04_twovariables

# %% [markdown]
# Standard imports

# %%
import numpy as np
import scipy.stats
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as pp

from IPython import display
from ipywidgets import interact, widgets

# %matplotlib inline

# %%
import re
import mailbox
import csv

# %%
gapminder = pd.read_csv('gapminder.csv')
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14740 entries, 0 to 14739
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           14740 non-null  object
#  1   year              14740 non-null  int64
#  2   region            14740 non-null  object
#  3   population        14740 non-null  float64
#  4   life_expectancy   14740 non-null  float64
#  5   age5_surviving    14740 non-null  float64
#  6   babies_per_woman  14740 non-null  float64
#  7   gdp_per_capita    14740 non-null  float64
#  8   gdp_per_day       14740 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
#Country_data = gapminder[(gapminder['country'] == 'Italy') | (gapminder['country'] == 'United States')]
Country_data = gapminder.query('(country == "Somalia") or (country == "Syria")')

size = np.where(Country_data['year'] %10 == 0, 30, 2)
color = np.where(Country_data['country'] == 'Somalia', 'Blue', 'Red')

ax = Country_data.plot.scatter('gdp_per_day', 'life_expectancy', logx= True, s = size, c = color)

Country_data[Country_data['country'] == 'Somalia'].plot.line(x = 'gdp_per_day', y = 'life_expectancy', ax = ax)
# Out:
# <AxesSubplot:xlabel='gdp_per_day', ylabel='life_expectancy'>

# %%
country = gapminder[gapminder['country'] == 'Somalia']
size = np.where(country['year'] %10 == 0, 30, 2)
country.plot.scatter('year', 'life_expectancy', s = size)

country.plot.scatter('year', 'gdp_per_day', s = size)
# Out:
# <AxesSubplot:xlabel='year', ylabel='gdp_per_day'>

# %%
Syria = gapminder[gapminder['country'] == 'Syria']
size = np.where(Italy['year'] %10 == 0, 30, 2)
Syria.plot.scatter('gdp_per_day', 'life_expectancy', logx= True, s = size)
